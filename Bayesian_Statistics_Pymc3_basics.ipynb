# %%
import pymc3 as pm
print(f"Running on PyMC3 v{pm.__version__}")
# Out:
# Running on PyMC3 v3.10.0

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import numpy as np
import pymc3 as pm
import arviz as az

# %%
import logging
logger = logging.getLogger("pymc3")
logger.propagate = False

# %% [markdown]
# # Question-1
# 1. Consider the first example we did in class where we wanted to find the probability p (for Heads) of a coin.
# Reproduce what we discussed in class as follows:
# (a) First construct a sampler with a known p value. You will use this to generate data for your Bayesian
# analysis for different values of p.
# (b) Using the following 4 priors i) non-informative ii) prior with a peak at p = 0.25 iii) prior with a peak at
# p = 0.5 and iv) prior with peak at p = 0.75 and the likelihood (you can use the one which was discussed
# in class) plot the posterior distribution as your generate data. In particular show plots for what happens
# after 1, 2, 3, 4 data points and after 1K and 4K data points. You can use a β-distribution to create the
# peaked priors.
# (c) Also, check what happens when you do the first 4 data items one-by-one versus after all four items are
# available - whether you get the same posterior.
#
# ### 1a Below function genreates sample_set from Bernouli distribution, with input parameter and sample size set.

# %%
def return_sampleset(par_p,size):
  return np.random.binomial(size=size, n=1, p= par_p)

# %% [markdown]
# ### 4000 size sample set for p=0.75

# %%
y_org_data=return_sampleset(0.75,4000)

# %%
y_org_data[0:4]
# Out:
# array([1, 1, 1, 1])

# %% [markdown]
# ### 1b : plots of posterior distrbution for following priors, with 1,2,3, 4, 1k, 4k datapoints. taking all data at once
# ### reference : https://github.com/aloctavodia/Doing_bayesian_data_analysis/blob/master/07_BernBetaPyMCFull.py (referred model details )
#  following are unifrom prior, prior peak at $\theta$ = 0.25, weak prior peak at $\theta$ = 0.5 and prior with peak at $\theta$=0.75 respectively
#
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
datapoints=[1,2,3,4,1000,4000]
priors = [[1,1],[2,3],[4,4],[3,2]]
prtitle= ['Non_informative','weak peak at 0.25','peak at 0.5','weak peak at 0.75']

fig, ax = plt.subplots(4,len(datapoints))

for p in range(len(priors)):
  for  i in range(len(datapoints)) :
    with pm.Model() as model:
      # define the prior
      theta = pm.Beta('theta', priors[p][0], priors[p][1])  # prior
      # define the likelihood
      y = pm.Bernoulli('y', p=theta, observed=y_org_data[0:datapoints[i]])
      # Generate a MCMC chain
      trace = pm.sample(500)
    title = prtitle[p]+'datapoints- '+str(datapoints[i])  
    #ax[p, i].hist(trace['theta'], color='skyblue')
    pm.plot_posterior(trace['theta'], ax=ax[p,i], color='skyblue');
    ax[p, i].set_title(title) 
    ax[p, i].set_xlim(0, 1)
    ax[p, i].set_xlabel(r'$\theta$')
    #ax[i].set_ylabel('Position in Chain')  

fig.set_figheight(13)
fig.set_figwidth(18)
fig.tight_layout() 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
# ...

# %% [markdown]
# ### 1c plots of posterior distrbution for following priors, with 1,2,3, 4 datapoints. 4 data items one-by-one versus taking data points all at once.

# %%
datapoints=y_org_data[0:4]
priors = [[1,1],[2,3],[4,4],[3,2]]
prtitle= ['Non_informative','weak peak at 0.25','peak at 0.5','weak peak at 0.75']

fig, ax = plt.subplots(4,len(datapoints)+1)

# taking data points one at a time
for p in range(len(priors)):
  pa = priors[p][0]
  pb = priors[p][1]
  for  i in range(len(datapoints)) :
    with pm.Model() as model:
      # define the prior
      theta = pm.Beta('theta', pa, pb)  # prior
      # define the likelihood
      y = pm.Bernoulli('y', p=theta, observed=datapoints[i])
      # Generate a MCMC chain
      trace = pm.sample(500)
    if datapoints[i]==1:
      pa+=1
    else:
      pb+=1    
    title = prtitle[p]+'datapoint no- '+str(i+1)  
    #ax[p, i].hist(trace['theta'], color='skyblue')
    pm.plot_posterior(trace['theta'], ax=ax[p,i], color='skyblue',hdi_prob=0.95);
    ax[p, i].set_title(title) 
    ax[p, i].set_xlim(0, 1)
    ax[p, i].set_xlabel(r'$\theta$')
    #ax[i].set_ylabel('Position in Chain') 

# taking data points all  at once
for p in range(len(priors)):
  with pm.Model() as model:
      # define the prior
      theta = pm.Beta('theta', priors[p][0], priors[p][1])  # prior
      # define the likelihood
      y = pm.Bernoulli('y', p=theta, observed=datapoints)
      # Generate a MCMC chain
      trace = pm.sample(500)
  title = prtitle[p]+'4 datapoints'+str(i+1)  
  pm.plot_posterior(trace['theta'], ax=ax[p,4], color='red',hdi_prob=0.95);
  ax[p, 4].set_title(title) 
  ax[p, 4].set_xlim(0, 1)
  ax[p, 4].set_xlabel(r'$\theta$')




fig.set_figheight(13)
fig.set_figwidth(18)
fig.tight_layout() 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [theta]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
# ...

# %% [markdown]
# #Question-2
# 2. Consider the height-weight correlation example. Build a Bayesian model for the correlation by finding posteriors for β0, β1, σ as follows:
# (a) First create a data generator by assuming reasonable values for the three parameters β0, β1, σ. To generate
# a data point w first draw a height value h ∼ N (µh, σh) (choose µh, σh suitably), then use the regression
# equation to generate a predicted value, say ˆw, draw the sample data point using w ∼ N ( ˆw, σ).
# (b) For two priors given below compute the posterior distributions for the three parameters for sample sizes
# of 10, 100 and 1000 and plot the distribution and the 95% HDI.
# The two priors are: i) a non-informative prior (done in class) and ii) a more informed prior created by
# drawing 10 data points using the generator in part (a) and then using N (µ
# 0
# , σ0
# ) as the prior where µ
# 0
# , σ0
# are the sample mean and sample standard deviation of the ten-sized sample.
#
#
#
#
#
#
# ## A simple description for ht-wt is a linear dependence wˆ = β1h + β2 where β1, β0 are the two parameters of the formula and ˆw is the predicted value of the weight and h is the height.(src : class notes).
#
#
# h ∼ N (5, 0.5)
# $\beta$1  = 0.75
# $\beta$2  = 15
# $\sigma$   = 1
# refrence -https://docs.pymc.io/notebooks/getting_started.html

# %%
def generate_hw(no_of_datapnt):
  beta1=0.75
  beta2=15
  sig= 1
  hights = np.random.normal(5,0.5,no_of_datapnt)
  wights = []
  for i in hights:
    temp_wt = i*beta1+beta2
    wights.append(np.random.normal(temp_wt,sig,1)[0])
  return hights,wights

# %% [markdown]
# # Weak prior

# %%
datax,datay=generate_hw(1000)
master_x,master_y=datax,datay
fig, ax = plt.subplots(3, 3)
for i in range(3):
  reg1_model = pm.Model()
  with reg1_model:
    # Priors for unknown model parameters
    beta1 = pm.Uniform("beta1",lower = -100,upper=100, shape=1 )
    beta2 = pm.Uniform("beta2", lower=-100, upper = 100, shape=1)
    sigma = pm.Uniform("sigma",lower =0, upper = 100)
    #sigma = pm.HalfNormal("sigma", sigma=1)
    # Expected value of outcome
    mu = beta2+ beta1 * datax[0:10**(i+1)] 
    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=datay[0:10**(i+1)])
    trace = pm.sample(500, return_inferencedata=False)
    #display(az.summary(trace, round_to=2))
  plotvar = trace.varnames[3:]
  count = 0
  for j in plotvar:
    pm.plot_posterior(trace[j], ax=ax[i, count], color='skyblue',hdi_prob=0.95)
    title = 'Non informative:'+str(10**(i+1))+'-datapoints'
    ax[i, count].set_title(title) 
    #ax[i, count].set_xlim(0, 1)
    ax[i, count].set_xlabel(j)
    count+=1


fig.set_figheight(10)
fig.set_figwidth(10)
fig.tight_layout() 
plt.show()     
#fig, ax = plt.subplots(2, 3)
 #pm.plot_posterior(theta_sample, ax=ax[0, 0], color='skyblue');
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /root/.theano/compiledir_Linux-4.19.112+-x86_64-with-Ubuntu-18.04-bionic-x86_64-3.6.9-64/lock_dir/lock
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, beta2, beta1]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
# ...

# %% [markdown]
# ## construction of informative prior.
# ## simulate the model on 10 data points and collect sample mean and sample standard distribution for three paramneters
# ## Consider Normal distributions around these sample mean and standard distributins as informative priors for rhe model

# %%
# simulation 10 sample points
samplex,sampley = generate_hw(10)
reg1_model = pm.Model()
with reg1_model:
  # Priors for unknown model parameters
  beta1 = pm.Uniform("beta1",lower = -100,upper=100, shape=1 )
  beta2 = pm.Uniform("beta2", lower=-100, upper = 100, shape=1)
  sigma = pm.Uniform("sigma",lower =0, upper = 100)
  #sigma = pm.HalfNormal("sigma", sigma=1)
  # Expected value of outcome
  mu = beta2+ beta1 * datax[0:10**(i+1)] 
  # Likelihood (sampling distribution) of observations
  Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=datay[0:10**(i+1)])
  trace = pm.sample(500, return_inferencedata=False)
beta1_smean,beta1_ssd = np.mean(trace['beta1']),np.std(trace['beta1'])
beta2_smean,beta2_ssd =np.mean(trace['beta2']),np.std(trace['beta2'])
sigma_smean,sigma_ssd =np.mean(trace['sigma']),np.std(trace['sigma'])
print(beta1_smean,beta1_ssd)

### Get parameter ditributions from informative prior
fig, ax = plt.subplots(3, 3)
for i in range(3):
  reg1_model = pm.Model()
  with reg1_model:
    # Priors for unknown model parameters
    beta1 = pm.Normal("beta1",mu=beta1_smean,sigma=beta1_ssd, shape=1 )
    beta2 = pm.Normal("beta2", mu=beta2_smean,sigma=beta2_ssd, shape=1)
    sigma = pm.Normal("sigma",mu=sigma_smean,sigma=sigma_ssd)
    #sigma = pm.HalfNormal("sigma", sigma=1)
    # Expected value of outcome
    mu = beta2+ beta1 * datax[0:10**(i+1)] 
    # Likelihood (sampling distribution) of observations
    Y_obs = pm.Normal("Y_obs", mu=mu, sigma=sigma, observed=datay[0:10**(i+1)])
    trace1 = pm.sample(500, return_inferencedata=False)
    #display(az.summary(trace, round_to=2))
  plotvar = trace1.varnames
  count = 0
  for j in plotvar:
    pm.plot_posterior(trace1[j], ax=ax[i, count], color='skyblue',hdi_prob=0.95)
    title = 'informative:'+str(10**(i+1))+'-datapoints'
    ax[i, count].set_title(title) 
    #ax[i, count].set_xlim(0, 1)
    ax[i, count].set_xlabel(j)
    count+=1


fig.set_figheight(10)
fig.set_figwidth(10)
fig.tight_layout() 
plt.show()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sigma, beta2, beta1]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 00:06<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
# ...
